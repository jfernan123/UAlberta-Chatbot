# %% [markdown]
# # Chatbot Test Suite Results
#
# - **Date:** 2026-04-24 23:00
# - **Model:** chatbot_graph (Claude Haiku)
# - **Questions:** 41
# - **Total time:** 192.4s

# %% [markdown]
# ---
#
# ## EASY (12 questions)

# %% [markdown]
# ### Q1: What are the prerequisites for STAT 471?
#
# **Time:** 4.1s
#
# ---
#
# According to the course information provided, **STAT 471: Probability I** has the following prerequisites:
#
# - **STAT 371** (Probability and Stochastic Processes)
# - **STAT 281**
#
# Note: STAT 471 is a Year 4 undergraduate course.

# %% [markdown]
# ### Q2: What are the prerequisites for MATH 209?
#
# **Time:** 2.4s
#
# ---
#
# According to the course information provided, **MATH 209: Calculus for Engineering III** has the following prerequisite:
#
# - **MATH 101**

# %% [markdown]
# ### Q3: What are the prerequisites for STAT 265?
#
# **Time:** 4.2s
#
# ---
#
# According to the course information provided, **STAT 265: Probability and Statistics I** has **no prerequisites** — it is an entry-level course.
#
# However, note that STAT 265 has **MATH corequisites**:
# - **MATH 209**
# - **MATH 214**
# - **MATH 217**
#
# This means you must be taking (or have already completed) one of these MATH courses alongside STAT 265.

# %% [markdown]
# ### Q4: What are the prerequisites for STAT 378?
#
# **Time:** 2.9s
#
# ---
#
# According to the course information provided, **STAT 378: Applied Regression Analysis** has the following prerequisites:
#
# - **STAT 266** (Probability and Statistics II)
# - **STAT 276**
#
# This is a Year 3 course and is a required course in both the Major and Honors Statistics programs at the University of Alberta.

# %% [markdown]
# ### Q5: Does STAT 151 have any prerequisites?
#
# **Time:** 3.0s
#
# ---
#
# According to the course information provided, **STAT 151: Introduction to Applied Statistics I** has the following prerequisite:
#
# - **Mathematics 30-1 or 30-2** (high school level mathematics)
#
# However, it is considered an **entry-level course** for university-level statistics. Note that while STAT 151 itself has no university-level prerequisites, credit can be obtained in at most one of STAT 151, STAT 161, and STAT 235, and it may not be taken for credit if you've already completed STAT 222, STAT 266, STAT 276, KIN 109, PEDS 109, PSYCH 211, PTHER 352, SCI 151, or SOC 210.

# %% [markdown]
# ### Q6: What first year math courses are available?
#
# **Time:** 4.2s
#
# ---
#
# # First Year Math Courses Available
#
# Based on the course information provided, here are the **first year (100-level) math courses** available at the University of Alberta:
#
# ## Calculus Courses:
# - **MATH 100**: Calculus for Engineering I
# - **MATH 101**: Calculus for Engineering II (prerequisite: MATH 100)
# - **MATH 117**: Honors Calculus I
# - **MATH 118**: Honors Calculus II (prerequisite: MATH 117)
# - **MATH 134**: Calculus for the Life Sciences I
# - **MATH 136**: Calculus for the Life Sciences II (prerequisite: MATH 134)
# - **MATH 144**: Calculus for the Mathematical and Physical Sciences
# - **MATH 146**: Calculus for the Mathematical and Physical Sciences (prerequisite: MATH 144)
# - **MATH 154**: Calculus for Business and Economics I
# - **MATH 156**: Calculus for Business and Economics II (prerequisite: MATH 154)
#
# ## Linear Algebra Courses:
# - **MATH 102**: Applied Linear Algebra
# - **MATH 125**: Linear Algebra I
# - **MATH 127**: Honors Linear Algebra I
#
# ## Other Courses:
# - **MATH 111, MATH 113, MATH 114, MATH 115, MATH 160**
#
# These courses serve different program requirements and student backgrounds. If you need help choosing which course is right for you, I'd recommend speaking with an academic advisor!

# %% [markdown]
# ### Q7: What 400-level STAT courses are offered?
#
# **Time:** 3.9s
#
# ---
#
# # 400-Level STAT Courses Offered
#
# Based on the course information provided, here are the **400-level STAT courses** available at the University of Alberta:
#
# - **STAT 413**: Computing for Data Science
# - **STAT 432**: Survival Analysis
# - **STAT 437**: Applied Statistical Methods
# - **STAT 441**: Statistical Methods for Learning and Data Mining
# - **STAT 453**: Risk Theory
# - **STAT 471**: Probability I
# - **STAT 479**: Time Series Analysis
# - **STAT 497**: Reading in Statistics
# - **STAT 498**: Statistical Topics in Data Science
# - **STAT 499**: Research Project
#
# These courses are available for students pursuing Statistics majors, honors, or minors, and many have specific prerequisites. If you'd like to know the prerequisites for any of these courses, feel free to ask!

# %% [markdown]
# ### Q8: What 300-level STAT courses are available?
#
# **Time:** 3.7s
#
# ---
#
# # 300-Level STAT Courses Available
#
# Based on the course information provided, here are the **300-level STAT courses** available at the University of Alberta:
#
# - **STAT 337**: Biostatistics
#   - Prerequisites: STAT 151, STAT 161, SCI 151
#
# - **STAT 353**: Life Contingencies I
#   - Prerequisites: MATH 253, STAT 265, STAT 281
#
# - **STAT 361**: Sampling Techniques
#   - Prerequisites: STAT 266, STAT 276
#
# - **STAT 368**: Introduction to Design and Analysis of Experiments
#   - Prerequisites: STAT 266, STAT 276
#
# - **STAT 371**: Probability and Stochastic Processes
#   - Prerequisites: STAT 265
#
# - **STAT 372**: Mathematical Statistics
#   - Prerequisites: STAT 266, STAT 276
#
# - **STAT 378**: Applied Regression Analysis
#   - Prerequisites: STAT 266, STAT 276
#
# These courses are part of the third-year offerings in Statistics and have varying prerequisite requirements, so be sure to check that you meet the prerequisites before enrolling.

# %% [markdown]
# ### Q9: What second year statistics courses are there?
#
# **Time:** 4.2s
#
# ---
#
# # Second Year (200-Level) STAT Courses Available
#
# Based on the course information provided, here are the **second year (200-level) STAT courses** available at the University of Alberta:
#
# - **STAT 235**: Introductory Statistics for Engineering
#   - No prerequisites listed
#
# - **STAT 252**: Introduction to Applied Statistics II
#   - Prerequisites: STAT 151, STAT 161, STAT 235, STAT 141, or SCI 151
#
# - **STAT 265**: Probability and Statistics I
#   - No prerequisites
#
# - **STAT 266**: Probability and Statistics II
#   - Prerequisites: STAT 265, STAT 281
#
# - **STAT 276**: Statistics for Data Science
#   - Prerequisites: STAT 265, STAT 281
#
# - **STAT 281**: Probability by Counting and Queuing
#   - No prerequisites listed
#
# If you need more detailed information about any of these courses or have questions about which course might be right for you, feel free to ask!

# %% [markdown]
# ### Q10: What is the Decima Robinson Support Centre?
#
# **Time:** 4.6s
#
# ---
#
# # The Decima Robinson Support Centre
#
# The **Decima Robinson Support Centre** is a comprehensive support service for students taking **100- and 200-level mathematics and statistics courses** at the University of Alberta.
#
# ## Location & Hours
# - **Location:** University Commons 1-200
# - **Hours:**
#   - Monday, Wednesday, Friday: 9 AM to 3 PM
#   - Tuesday, Thursday: 10 AM to 4 PM
#   - (Open during Fall and Winter terms when classes are taught)
#
# ## Services Offered
# The Centre provides:
# - **One-on-one help** with homework on a drop-in basis
# - **Exam study sessions** for select courses
# - **Precalculus program** for students refreshing high school math skills while taking calculus
# - **Weekly review seminars**
# - **Primer Courses** to help high school students transition to university
#
# ## Staff
# The Centre is staffed by graduate students who are available to help students with their coursework.
#
# ## Contact
# For questions about services or feedback, you can:
# - Stop by **University Commons 1-200** in person
# - Email: **mssdrsc@ualberta.ca**
#
# ## Historical Note
# The Centre was named after **Decima Robinson**, the first BSc graduate at the University of Alberta, who graduated with a major in mathematics in 1911.

# %% [markdown]
# ### Q11: Where can I get help with my calculus homework?
#
# **Time:** 4.2s
#
# ---
#
# # Getting Help with Your Calculus Homework
#
# For help with your calculus homework, I recommend visiting the **Decima Robinson Support Centre**!
#
# The Decima Robinson Support Centre is a comprehensive support service specifically designed to help students taking **100- and 200-level mathematics and statistics courses** at the University of Alberta. Whether you're stumped by a tricky homework question or need clarification on course concepts, the support centre is there to assist you.
#
# For more information about the Decima Robinson Support Centre, including hours, location, and how to access their services, visit the [Math & Stats Help page](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/undergraduate-studies/decima-support-centre/index.html).

# %% [markdown]
# ### Q12: Is there tutoring available for statistics students?
#
# **Time:** 4.5s
#
# ---
#
# # Tutoring and Support for Statistics Students
#
# Yes! **The Decima Robinson Support Centre** provides comprehensive support for statistics students.
#
# ## What They Offer:
#
# The Decima Robinson Support Centre is available to help students taking **100- and 200-level mathematics and statistics courses**. They can assist you with:
#
# - Homework questions
# - Course concepts and material
# - Problem-solving strategies
#
# ## How to Access Support:
#
# If you need help with your statistics coursework, visit the **Decima Robinson Support Centre**. They offer both structured programs and drop-in help options.
#
# For more information or specific details about their current hours and services, you can contact the Math & Statistics department or visit their support centre directly.

# %% [markdown]
# ---
#
# ## MEDIUM (14 questions)

# %% [markdown]
# ### Q13: What is the difference between an Honors and a Major in Mathematics?
#
# **Time:** 5.1s
#
# ---
#
# # Honors vs. Major in Mathematics
#
# Based on the information available from the University of Alberta Math & Statistics department, I don't have specific details comparing the differences between an **Honors** and a **Major** in Mathematics in the course information provided.
#
# However, I can tell you that:
#
# - **Honors in Mathematics** is available as either a **BSc Honors** (through the Faculty of Science) or a **BA Honors** (through the Faculty of Arts)
#
# For detailed information about the specific differences between Honors and Major programs, including:
# - Course requirements
# - Thesis or capstone requirements
# - Career outcomes
# - Application processes
#
# I recommend:
# 1. **Visiting the department website**: https://www.ualberta.ca/en/mathematical-and-statistical-sciences/undergraduate-studies/
# 2. **Contacting the Math & Statistics department directly** for program-specific guidance
# 3. **Consulting with an academic advisor** in the Faculty of Science or Faculty of Arts (depending on which degree type interests you)
#
# Is there anything else about specific math courses or support services I can help you with?

# %% [markdown]
# ### Q14: What is the difference between STAT 151 and STAT 265?
#
# **Time:** 5.2s
#
# ---
#
# # Difference Between STAT 151 and STAT 265
#
# Based on the course information available, here are the key differences:
#
# ## STAT 151 - Introduction to Applied Statistics I
#
# **Level:** Introductory/Foundation course
# - **Prerequisites:** Mathematics 30-1 or 30-2 (high school level)
# - **Content:** Covers foundational applied statistics topics including:
#   - Data collection and presentation
#   - Descriptive statistics
#   - Probability distributions and sampling distributions
#   - Central limit theorem
#   - Point estimation, confidence intervals, and hypothesis testing
#   - Correlation and regression analysis
#   - ANOVA
#   - Goodness of fit and contingency tables
#
# ## STAT 265 - Probability and Statistics I
#
# **Level:** Upper-level course (appears in Senior Courses for Statistics programs)
# - **Prerequisites:** Not specified in the available information
# - **Content:** More advanced probability and statistics theory
#
# ## Key Takeaway
#
# **STAT 151** is an **introductory course** designed for students with high school mathematics background, while **STAT 265** appears to be a more **advanced, theory-focused course** for students further along in their statistics studies.
#
# If you need more detailed information about STAT 265's specific content and prerequisites, I'd recommend checking the course calendar or contacting the Math & Statistics department directly.

# %% [markdown]
# ### Q15: What is the difference between the Mathematics and Statistics programs?
#
# **Time:** 5.5s
#
# ---
#
# # Difference Between Mathematics and Statistics Programs
#
# Based on the information available from the University of Alberta Math & Statistics department, I don't have detailed course-by-course comparisons between the two programs in my current resources.
#
# However, I can tell you that:
#
# ## Program Options Available
#
# Both **Mathematics** and **Statistics** offer similar degree structures:
# - **Honors** programs (available in both BSc and BA)
# - **Major** programs (available in both BSc and BA)
# - **Minor** programs (available in both BSc and BA)
#
# ## Key Difference in BA Options
#
# One notable difference is that through the **Faculty of Arts**, you can pursue:
# - **BA Honors in Mathematics** or a **Major/Minor in Mathematics**
# - **Minor in Statistics** (but **not** a Major in Statistics through the BA)
#
# ---
#
# ## For More Detailed Information
#
# For a comprehensive comparison of the specific courses, focus areas, and career outcomes for each program, I recommend:
#
# 1. **Visiting the program pages directly:**
#    - Mathematics program page
#    - Statistics program page
#
# 2. **Contacting the department:** The Undergraduate Contact for the Department of Mathematical and Statistical Sciences can provide detailed guidance on which program best suits your interests and goals.
#
# Is there a specific aspect of these programs you'd like to know more about?

# %% [markdown]
# ### Q16: What are the requirements for honors math?
#
# **Time:** 6.3s
#
# ---
#
# # Requirements for Honors in Mathematics
#
# The **Honors in Mathematics program** requires **63 units** and includes the following components:
#
# ## Foundation Courses (12 units):
# - **CMPUT 174** - Introduction to the Foundations of Computation I
# - **CMPUT 175** - Introduction to the Foundations of Computation II
#   *(Note: CMPUT 274 and CMPUT 275 can serve as substitutes)*
#
# - **Choose 3 units from (Calculus I):**
#   - MATH 117 - Honors Calculus I
#   - MATH 134 - Calculus for the Life Sciences I
#   - MATH 144 - Calculus for the Mathematical and Physical Sciences I
#   - MATH 154 - Calculus for Business and Economics I
#
# - **Choose 3 units from (Calculus II):**
#   - MATH 118 - Honors Calculus II
#   - MATH 136 - Calculus for the Life Sciences II
#   - MATH 146 - Calculus for the Mathematical and Physical Sciences II
#   - MATH 156 - Calculus for Business and Economics II
#
# - **Choose 3 units from (Linear Algebra):**
#   - MATH 125 - Linear Algebra I
#   - MATH 127 - Honors Linear Algebra I
#
# ## Senior Courses (51 units):
# A selection of advanced mathematics courses including MATH 216, MATH 217, MATH 226, MATH 317, MATH 327, MATH 329, MATH 336, MATH 411, MATH 417, MATH 418, MATH 429, MATH 447, MATH 448, MATH 499, plus electives in Linear Algebra and Statistics.
#
# **Note:** Students must also satisfy Common Course Requirements, Major/Honors/Minor Requirements, and Science and Senior Course Level requirements for the Bachelor of Science program.

# %% [markdown]
# ### Q17: What are the requirements for the major in statistics?
#
# **Time:** 8.4s
#
# ---
#
# # Requirements for Major in Statistics
#
# The **Major in Statistics program** requires **54 units** and includes the following components:
#
# ## Foundation Courses (18 units):
# - **CMPUT 174** - Introduction to the Foundations of Computation I
# - **CMPUT 175** - Introduction to the Foundations of Computation II
# - **STAT 151** - Introduction to Applied Statistics I
# - Choose 3 units from one of these Calculus I courses:
#   - MATH 117 - Honors Calculus I
#   - MATH 134 - Calculus for the Life Sciences I
#   - MATH 144 - Calculus for the Mathematical and Physical Sciences I
#   - MATH 154 - Calculus for Business and Economics I
# - Choose 3 units from one of these Calculus II courses:
#   - MATH 118 - Honors Calculus II
#   - MATH 136 - Calculus for the Life Sciences II
#   - MATH 146 - Calculus for the Mathematical and Physical Sciences II
#   - MATH 156 - Calculus for Business and Economics II
# - Choose 3 units from one of these Linear Algebra courses:
#   - MATH 125 - Linear Algebra I
#   - MATH 127 - Honors Linear Algebra I
#
# ## Senior Courses (36 units):
# - **MATH 216** - Introduction to Analysis
# - **STAT 252** - Introduction to Applied Statistics II
# - **STAT 265** - Probability and Statistics I
# - **STAT 266** - Probability and Statistics II
# - **STAT 371** - Probability and Stochastic Processes
# - **STAT 372** - Mathematical Statistics
# - **STAT 378** - Applied Regression Analysis
# - Choose 3 units from:
#   - MATH 214 - Calculus III, or
#   - MATH 217 - Honors Calculus III
# - Choose 3 units from:
#   - MATH 225 - Linear Algebra II, or
#   - MATH 227 - Honors Linear Algebra II
# - Choose 3 units from any 300- or 400-level MATH or STAT course
# - Choose 6 units from any 400-level STAT course
#
# **Note:** Students registered in the Bachelor of Science (Major) program also need to satisfy Common Course Requirements, Major Requirements, and Science and Senior Course Level Requirements.

# %% [markdown]
# ### Q18: How many units do I need for a minor in mathematics?
#
# **Time:** 3.9s
#
# ---
#
# # Units Required for a Minor in Mathematics
#
# A **Minor in Mathematics** requires **24 units**.
#
# ## Breakdown:
#
# The 24 units must include:
# - **At least 6 units at the 300-level or higher** in MATH courses
#
# The remaining units can be chosen from 200-, 300-, and 400-level MATH or MA PH courses, following the specific course selection requirements outlined in the program.

# %% [markdown]
# ### Q19: What programs are available in Mathematics and Statistics?
#
# **Time:** 5.0s
#
# ---
#
# # Programs Available in Mathematics and Statistics
#
# The University of Alberta Department of Mathematical and Statistical Sciences offers a variety of undergraduate degree programs:
#
# ## Degree Types Available:
#
# - **Honors Programs** - in Mathematics and Statistics
# - **Major Programs** - in Mathematics and Statistics
# - **Minor Programs** - in Mathematics and Statistics
#
# As one of the largest departments of mathematics and statistics in Canada, the department is able to offer these diverse program options across both disciplines.
#
# ## Additional Program Information:
#
# For more detailed information about specific program requirements, course listings, and degree structures, I recommend:
#
# 1. **Visiting the degree types page** on the department website for comprehensive details
# 2. **Contacting the department directly** for advising inquiries about degree programs in Mathematics and Statistics
#
# The department also offers **graduate programs** (MSc and PhD) for students interested in advanced study.
#
# Is there a specific program you'd like to learn more about, such as the requirements for an Honors in Mathematics, a Major in Statistics, or a Minor in either discipline?

# %% [markdown]
# ### Q20: What is the Data Science program?
#
# **Time:** 5.8s
#
# ---
#
# # Data Science Program
#
# Based on the information available from the University of Alberta Math & Statistics department, there is an **Embedded Certificate in Data Science** rather than a standalone degree program.
#
# ## Embedded Certificate in Data Science
#
# This certificate is available to **graduate students** pursuing degrees in:
# - Pure Mathematics
# - Applied Mathematics
# - Mathematical Physics
#
# ### Requirements:
#
# To earn the certificate, students must complete:
# - **3 courses** (selected from a large list of options)
# - **Graduate Teaching and Learning Program (Level 1)**
#
# ### Important Notes:
#
# - The certificate is designed to provide **marketable skills for the non-academic job market**, while also being helpful in academic settings
# - Depending on individual circumstances, the courses taken for the certificate **may or may not count toward course requirements** in the actual degree program
#
# ---
#
# If you're interested in data science and would like more specific information about which courses are available or how this certificate might fit with your academic goals, I'd recommend contacting the Department of Mathematical and Statistical Sciences directly or visiting their graduate studies page.

# %% [markdown]
# ### Q21: What is the Applied Mathematics program?
#
# **Time:** 4.5s
#
# ---
#
# # Applied Mathematics Program
#
# Based on the information available from the University of Alberta Math & Statistics department, I don't have detailed program requirements for a specific **Applied Mathematics degree program** in my current resources.
#
# However, I can tell you about the **Applied Math Institute (AMI)**:
#
# ## Applied Math Institute (AMI)
#
# The **Applied Math Institute** was established in 1987 and:
# - Promotes fundamental and applied research on mathematical sciences
# - Stimulates collaborative research within the University of Alberta community
# - Regularly organizes seminars
# - Supports the publication of the **Canadian Applied Mathematics Quarterly (CAMQ)** — a Canadian scientific journal devoted to research articles related to the applications of mathematics
# - Supports national and international mathematical conferences and workshops
#
# ## For Program Information
#
# For specific details about Applied Mathematics degree programs (such as course requirements, units needed, etc.), I recommend:
#
# 1. **Visiting the [Programs section](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/undergraduate-studies/programs/index.html)** of the Math & Statistics department website
# 2. **Contacting an academic advisor** who can discuss your specific interests and guide you through program options
#
# Is there a specific aspect of applied mathematics or another program you'd like to know more about?

# %% [markdown]
# ### Q22: Can I double major in Math and Statistics?
#
# **Time:** 6.0s
#
# ---
#
# # Double Majoring in Math and Statistics
#
# Based on the information available from the University of Alberta Math & Statistics department, I don't have specific details about whether you can double major in both Mathematics and Statistics together.
#
# However, I can tell you that the University of Alberta does support double majors in general. According to the BSc General program requirements, students can complete a second Science major, and double majors will be recorded on your student transcript.
#
# ## What I'd Recommend:
#
# Since Mathematics and Statistics are closely related disciplines within the Department of Mathematical and Statistical Sciences, I'd suggest:
#
# 1. **Contact the department directly** - They can advise you on whether a Math/Statistics double major is feasible and how the course requirements would work together
# 2. **Speak with an academic advisor** - They can help you plan a course sequence that satisfies both major requirements
#
# The department is known for being flexible and working with students to find the right program fit, so they should be able to help you explore this option!
#
# Would you like information about the individual requirements for a **Major in Mathematics** or **Major in Statistics**?

# %% [markdown]
# ### Q23: What is the MDP program?
#
# **Time:** 4.3s
#
# ---
#
# # MDP Program (Master's in Modelling, Data + Predictions)
#
# The **MDP program** is a professionally-oriented, course-based Master's program offered by the Department of Mathematical and Statistical Sciences at the University of Alberta.
#
# ## Program Overview
#
# The MDP program is a **graduate training program in data science** that provides students with a unique combination of skills in:
# - Data modelling
# - Data analytics
# - Statistical machine learning algorithms
# - Modern computational methods
#
# ## Program Details
#
# - **Duration:** Designed to be completed in **16 months**
# - **Focus:** Emphasizes the practical aspects of mathematical and statistical modelling and data analysis
# - **Career Preparation:** Prepares graduates for related careers in industry and government
#
# This program is ideal if you're looking for a professionally-focused graduate degree that combines theoretical knowledge with practical, industry-relevant skills in data science and modelling.
#
# For more information about admission requirements or how to apply, you can visit the [graduate studies page](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/graduate-studies/index.html).

# %% [markdown]
# ### Q24: How do I apply to the MSc Statistics program?
#
# **Time:** 5.5s
#
# ---
#
# # How to Apply to the MSc Statistics Program
#
# To apply to the **MSc Statistics program** at the University of Alberta Department of Mathematical and Statistical Sciences, follow these steps:
#
# ## Step 1: Create an Account
# Access the **Application Portal** and create an account to choose your program and specialization.
#
# ## Step 2: Submit Required Documents
# All supporting documents must be uploaded **directly to the online application**. You will need to provide:
#
# ### Personal Documents:
# - **Curriculum Vitae** (PDF format)
# - **Personal Statement** (1-2 pages) outlining:
#   - Your background
#   - Your interest in mathematical or statistical sciences
#   - Your future plans
#
# ### Academic Documents:
# - **English Language Proficiency Examination Results**
# - **Official Academic Transcripts** from all post-secondary institutions attended (in original language or English translation)
# - **Degree Certificate** (in original language or English translation)
# - **School Documents**: Scan and upload each page (front and back) of official academic documents in PDF format
#
# ### References:
# - **3 Reference Letters** with the names and institutional email addresses of your referees
#
# ## Application Deadline
# **January 15, 2026** (including submission of references) for Fall 2026 entry
#
# The application portal for Fall 2026 entry is now open. For questions about the application process, contact the department directly.

# %% [markdown]
# ### Q25: What is the PhD program in Mathematics?
#
# **Time:** 5.2s
#
# ---
#
# # PhD Program in Mathematics
#
# The **PhD program in Mathematics** at the University of Alberta Department of Mathematical and Statistical Sciences is a research-focused doctoral program with the following key features:
#
# ## Program Duration
# - **Typically lasts 4 to 5 years**
#
# ## Admission Requirements
# To be admitted to the PhD program, you typically must:
# - Hold an **MSc degree in Mathematics or Statistics** (or equivalent from a recognized institution)
# - Meet the minimum MSc entrance requirements (GPA of 3.3 in the last 60 units of relevant undergraduate or graduate work)
#
# **Note:** Students with a BSc degree will typically be enrolled in the MSc program first. However, very strong students can transfer to the PhD program without first completing the MSc degree, subject to certain restrictions.
#
# ## Funding & Support
# - Most students in the thesis-based master's program and PhD program work as **teaching assistants** during the Fall and Winter terms
# - Students receive a **funding guarantee**
#
# ## Program Focus
# The PhD program is research-intensive and prepares students for careers in advanced mathematical research, academia, and specialized professional roles.
#
# If you have specific questions about research areas, supervisors, or the application process, I'd recommend contacting the Department of Mathematical and Statistical Sciences directly.

# %% [markdown]
# ### Q26: Is there funding available for graduate students?
#
# **Time:** 3.8s
#
# ---
#
# # Funding Available for Graduate Students
#
# Yes, there is funding available for graduate students in the Department of Mathematical and Statistical Sciences. Here's what you should know:
#
# ## Guaranteed Funding for International Students
# - **International students are guaranteed** to receive the same funding amounts as domestic students
# - International students receive an **additional approximate $4,500 per year** to help partially cover their increased tuition and program fees
#
# ## Important Note on Differential Fees
# - International students are charged a **Differential Fee** in addition to regular tuition fees
# - This differential fee **can be financially supported by your Supervisor**, but it is **not guaranteed**
# - Financial support for the differential fee depends on the funds available to your Supervisor
#
# ## Additional Resources for Graduate Students
#
# ### Graduate Students' Association (GSA)
# The **GSA** is a student-run organization that represents all Masters and PhD students at the University of Alberta. They offer:
# - Health and dental plan programs
# - Off-campus housing registry
# - Various awards and scholarships
#
# For more information, visit the [GSA site](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/graduate-studies/student-resources/index.html).
#
# For detailed information about specific funding opportunities and amounts, I recommend contacting the department's graduate studies office directly.

# %% [markdown]
# ---
#
# ## HARD (15 questions)

# %% [markdown]
# ### Q27: I want to study statistics. What courses should I take in first year?
#
# **Time:** 4.3s
#
# ---
#
# # First Year Statistics Courses
#
# If you want to study statistics, here are the **first-year (100-level) statistics courses** available:
#
# ## Statistics First Year Courses:
#
# - **STAT 151**: Introduction to Applied Statistics I
# - **STAT 161**: Introductory Statistics for Business and Economics
# - **STAT 181**: Introduction to Combinatorics and Probability
#
# ## Which Course Should You Take?
#
# The course you choose depends on your program and interests:
# - **STAT 151** is a general introduction to applied statistics
# - **STAT 161** is designed for students in business and economics programs
# - **STAT 181** focuses on combinatorics and probability theory
#
# ## Additional Support
#
# If you want to refresh your prerequisite statistics skills before starting your first-year course, the **Online Statistics Primer Course** is available. This is an optional, non-credit course that covers topics like linear functions, probability, descriptive statistics, and interpretations of statistical displays. Registration opens on May 1st on Marketplace.
#
# For more detailed information about which course fits your specific program requirements, I'd recommend checking your program's course requirements or contacting the Department of Mathematical and Statistical Sciences directly.

# %% [markdown]
# ### Q28: I've completed STAT 265 and STAT 281. What 300-level STAT courses can I take?
#
# **Time:** 5.6s
#
# ---
#
# # 300-Level STAT Courses You Can Take
#
# Based on your completion of **STAT 265** and **STAT 281**, here are the 300-level STAT courses you're eligible for:
#
# ## Available Courses:
#
# - **STAT 337: Biostatistics**
#   - Prerequisites: STAT 151, STAT 161, SCI 151
#   - ⚠️ *Note: You'll need to have completed STAT 151 and STAT 161*
#
# - **STAT 353: Life Contingencies I**
#   - Prerequisites: MATH 253 and one of STAT 265 or STAT 281
#   - ✓ *You meet the prerequisites!*
#
# - **STAT 361: Sampling Techniques**
#   - Prerequisites: STAT 266 or STAT 276
#   - ⚠️ *Note: You'll need to complete STAT 266 or STAT 276 first*
#
# - **STAT 368: Introduction to Design and Analysis of Experiments**
#   - Prerequisites: STAT 266 or STAT 276
#   - ⚠️ *Note: You'll need to complete STAT 266 or STAT 276 first*
#
# - **STAT 371: Probability and Stochastic Processes**
#   - Prerequisites: STAT 265
#   - ✓ *You meet the prerequisites!*
#
# - **STAT 372: Mathematical Statistics**
#   - Prerequisites: STAT 266 or STAT 276
#   - ⚠️ *Note: You'll need to complete STAT 266 or STAT 276 first*
#
# - **STAT 378: Applied Regression Analysis**
#   - Prerequisites: STAT 266 or STAT 276
#   - ⚠️ *Note: You'll need to complete STAT 266 or STAT 276 first*
#
# ## Summary:
# You can **immediately enroll** in **STAT 353** and **STAT 371**. For the others, you'll need to complete either **STAT 266** or **STAT 276** (or have already completed STAT 151 and STAT 161 for STAT 337).

# %% [markdown]
# ### Q29: What is the engineering calculus sequence?
#
# **Time:** 3.7s
#
# ---
#
# # Engineering Calculus Sequence
#
# The engineering calculus sequence at the University of Alberta consists of three courses:
#
# ## Engineering Calculus Courses:
#
# - **MATH 100** - Calculus for Engineering I
# - **MATH 101** - Calculus for Engineering II
# - **MATH 209** - Calculus for Engineering III
#
# These courses are specifically designed for engineering students and cover topics in calculus including differentiation, integration, and their applications relevant to engineering disciplines.
#
# If you have questions about which calculus sequence is right for your program, or need additional support with these courses, the **Decima Robinson Support Centre** offers tutoring and academic support services.

# %% [markdown]
# ### Q30: What courses do I need before taking STAT 471?
#
# **Time:** 2.9s
#
# ---
#
# # Prerequisites for STAT 471
#
# Based on the course information, **STAT 471: Probability I** has the following prerequisites:
#
# - **STAT 371** - Probability and Stochastic Processes
# - **STAT 281** - (specific course name not listed, but required)
#
# You must complete both of these courses before you can enroll in STAT 471.

# %% [markdown]
# ### Q31: What careers can I pursue with a Statistics degree?
#
# **Time:** 5.0s
#
# ---
#
# # Careers with a Statistics Degree
#
# That's a great question! Unfortunately, I don't have specific information about career outcomes and employment paths for Statistics graduates in the materials available to me from the University of Alberta Math & Statistics department.
#
# ## What I'd Recommend:
#
# To learn about career opportunities with a Statistics degree, I suggest:
#
# 1. **Contact the Department** - Reach out to the Department of Mathematical and Statistical Sciences directly. They can provide insights into where their graduates work and what careers they pursue.
#
# 2. **Visit the Department Website** - The undergraduate studies section may have additional resources about career pathways.
#
# 3. **Speak with Academic Advisors** - Advisors in the department can discuss how Statistics skills are applied in various industries and professions.
#
# 4. **Connect with Alumni** - The department may be able to connect you with Statistics graduates working in fields that interest you.
#
# Statistics is a highly versatile degree with applications across many sectors, but I want to make sure you get accurate, specific information from the department about their program outcomes and career support services.
#
# Is there anything else about the Statistics program itself that I can help you with?

# %% [markdown]
# ### Q32: What jobs are available for Data Science graduates?
#
# **Time:** 4.6s
#
# ---
#
# # Jobs Available for Data Science Graduates
#
# Based on information from the University of Alberta Department of Mathematical and Statistical Sciences, graduates with data science training are well-positioned for careers in several fields:
#
# ## Career Opportunities:
#
# - **Data Analysts** - in various industries
# - **Data Scientists** - in industry or government sectors
# - **Researchers** - in government agencies (e.g., Alberta Environment)
# - **Biostatisticians** - in hospitals and medical research facilities
# - **Actuaries and Financial Analysts** - with insurance firms
# - **Pension Administrators**
# - **Survey Methodologists** - with organizations like Statistics Canada
# - **Instructors and Researchers** - at post-secondary institutions
#
# ## Relevant Programs:
#
# The Department offers the **Master's in Modelling, Data + Predictions (MDP)** program, which is specifically designed to prepare graduates for work in industry or government as **data scientists and analysts**.
#
# ---
#
# If you're interested in pursuing data science studies at the University of Alberta, I'd be happy to provide more information about our graduate programs or undergraduate statistics courses that can prepare you for this field!

# %% [markdown]
# ### Q33: Are there research opportunities for undergrad students?
#
# **Time:** 4.1s
#
# ---
#
# # Research Opportunities for Undergraduate Students
#
# Yes, there are research opportunities available for undergraduate students in the Department of Mathematical and Statistical Sciences!
#
# ## USRA Program
#
# The department supports undergraduate research through the **NSERC Undergraduate Student Research Awards (USRA)** program. This is a competitive award that provides funding for eligible undergraduate students to conduct research.
#
# ## USRA Supplements
#
# NSERC offers additional supplements to USRA awards, including:
#
# - **Environment and Climate Change Canada Atmospheric and Meteorological Supplement** - Eligible USRA awardees must apply by August 1
# - **Canadian Forest Sector Workplace Diversity Supplement** - Automatically considered when you apply to the USRA program if you meet eligibility criteria
#
# ## Contact Information
#
# For questions about the awards themselves, contact:
# - **Dr. Nicolas Guay** (mssac@ualberta.ca)
#
# For inquiries about the administrative application process, contact:
# - **Tara Evans** (mssugrdgrad@ualberta.ca)
#
# I'd recommend reaching out to these contacts to learn more about eligibility requirements and how to apply for these research opportunities!

# %% [markdown]
# ### Q34: Is there a study abroad program for math students?
#
# **Time:** 4.2s
#
# ---
#
# # Study Abroad Programs for Math Students
#
# Unfortunately, I don't have specific information about study abroad programs for mathematics students in the materials available to me.
#
# For detailed information about study abroad opportunities, I'd recommend:
#
# 1. **Contacting the Department directly** - Reach out to the Department of Mathematical and Statistical Sciences at the University of Alberta
# 2. **Visiting the University's International Office** - They typically coordinate study abroad and exchange programs
# 3. **Speaking with an Academic Advisor** - They can provide information about international opportunities available to math students
#
# If you have other questions about our programs, courses, or department resources, I'm happy to help!

# %% [markdown]
# ### Q35: What student clubs are available for math and stats students?
#
# **Time:** 4.7s
#
# ---
#
# # Student Clubs for Math and Stats Students
#
# Unfortunately, I don't have detailed information about specific student clubs available for math and stats students in the materials currently available to me.
#
# However, the Department of Mathematical and Statistical Sciences does have **student links and resources** available. For information about student clubs and groups, I recommend:
#
# 1. **Visiting the Student Groups page** through the Office of the Registrar
# 2. **Checking Campus Life** resources at the University of Alberta
# 3. **Contacting the department directly** at **mssugrd@ualberta.ca** for undergraduate inquiries
#
# Additionally, the department hosts social events throughout the year, such as:
# - **Undergraduate Social** (for major, specialization, and honors students)
# - **Departmental Picnic** (for graduate students and staff)
#
# These are great opportunities to connect with other math and stats students!
#
# For more comprehensive information about student clubs and organizations, I'd recommend visiting the [Student Groups page](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/undergraduate-studies/student-clubs.html) or contacting the Students' Union.

# %% [markdown]
# ### Q36: What scholarships are available for math students?
#
# **Time:** 6.3s
#
# ---
#
# # Scholarships Available for Math Students
#
# There are several scholarships and awards available for mathematics students at the University of Alberta:
#
# ## Entrance Scholarships
#
# - **Academic Excellence Scholarships**: The Department awards **six scholarships worth $1,000 each** annually to students entering an Honors or Specialization program in Mathematics or Statistics based on superior academic achievement.
#   - Selection is based on Grade 11 and/or Grade 12 final marks
#   - Exceptional mathematical ability, performance in math courses, math competition results, and organization of mathematical activities may also be considered
#   - **No application necessary** — recipients are selected by the department
#
# ## Undergraduate Scholarships and Prizes
#
# The Department awards many additional scholarships and prizes each year thanks to generous donors. For a complete list of available undergraduate awards, visit the **Office of the Registrar's Mathematical and Statistical Sciences Scholarships and Awards page**.
#
# ## Graduate Scholarships
#
# - **Vanier Scholarships**: Prestigious scholarships worth **$50,000 per year** available to incoming PhD students. These are highly competitive and awarded to exceptional students.
#
# For more details about all available scholarships and awards, I recommend contacting the Department directly or visiting their awards and scholarships page.

# %% [markdown]
# ### Q37: What is the Statistical Consulting service?
#
# **Time:** 4.6s
#
# ---
#
# # Statistical Consulting Service
#
# The Department of Mathematical and Statistical Sciences offers a **Statistical Consulting service** through the Statistics Division:
#
# ## Internal Consulting (Courtesy Service)
# The department provides a **courtesy consulting service** funded by the department for members of the University community. This serves as a training facility for graduate students in applied statistics, allowing them to gain practical experience while helping other researchers on campus.
#
# ## External Consulting (Fee-for-Service)
# The department also offers **statistical consulting for external clients** in business, government, and industry on a **fee-for-service basis**.
#
# ## Purpose
# The consulting service serves as a centre for discussion of research problems and methodological advances in statistics and probability, helping both internal and external clients with their statistical needs.
#
# For more information about accessing these consulting services, I'd recommend contacting the Department of Mathematical and Statistical Sciences directly.

# %% [markdown]
# ### Q38: Does the department offer any consulting or training for researchers?
#
# **Time:** 4.6s
#
# ---
#
# # Consulting and Training Services for Researchers
#
# Yes, the Department of Mathematical and Statistical Sciences offers comprehensive consulting and training services for researchers!
#
# ## Training and Consultation Centre (TCC)
#
# The department operates a **Training and Consultation Centre** that provides services to:
# - University-affiliated researchers
# - Staff members
# - Graduate students working on theses
#
# ### Services Available:
#
# **Internal Consulting (Courtesy Service)**
# - A courtesy consulting service funded by the department for members of the University community
#
# **Dedicated Services**
# - Projects requiring involved or long-term support and/or collaboration
# - Offered on an individual basis by department consultants
#
# **External Consulting**
# - Statistical consulting for external clients in business, government, and industry
# - Available on a fee-for-service basis
#
# ## Statistics Division
#
# The **Statistics Division** within the department also:
# - Serves as a training facility for graduate students in applied statistics
# - Provides a centre for discussion of research problems and methodological advances in statistics and probability
#
# For more details about available services, you can visit the [Training and Consultation Centre page](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/training-consultation-centre/index.html).

# %% [markdown]
# ### Q39: I'm a high school student interested in math. What outreach programs exist?
#
# **Time:** 5.7s
#
# ---
#
# # Outreach Programs for High School Students
#
# Great question! The Department of Mathematical and Statistical Sciences offers several outreach programs for high school students interested in mathematics:
#
# ## Alberta High School Math Competition
#
# The department hosts the **Alberta High School Math Competition**, which is a great way to challenge yourself and test your mathematical skills:
#
# - **Format**: An 80-minute paper with 16 multiple-choice questions
# - **Timing**: Held in the morning of the third Tuesday of November
# - **School Teams**: The top three students in each school form the School Team
#
# This is an excellent opportunity to compete with other talented math students across Alberta!
#
# ## Diversity in Mathematics Summer School
#
# The University of Alberta, in partnership with the University of British Columbia and PIMS (Pacific Institute of Mathematical Sciences), runs **summer schools targeted at high school and undergraduate students** who identify as members of a minority group.
#
# **Goals of the program:**
# - Introduce students to new areas of mathematics and statistics
# - Provide information about opportunities in math and science careers
# - Build community among students and faculty from throughout Western Canada
#
# For more details about these programs and other outreach activities, I'd recommend visiting the [department's outreach page](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/outreach/).
#
# Is there anything else you'd like to know about studying math at the University of Alberta?

# %% [markdown]
# ### Q40: What is the difference between the honors statistics and honors mathematics programs?
#
# **Time:** 6.8s
#
# ---
#
# # Difference Between Honors Statistics and Honors Mathematics Programs
#
# Based on the information available, I can provide some details about the **Honors in Statistics** program, but I don't have complete course information for the **Honors in Mathematics** program to give you a full comparison.
#
# ## What I Can Tell You:
#
# ### Honors in Statistics (66 units)
# The Honors Statistics program includes:
# - **Foundation courses** in computation (CMPUT 174, 175), calculus, linear algebra, and introductory statistics
# - **Senior courses** heavily focused on probability and statistics, including:
#   - STAT 371 - Probability and Stochastic Processes
#   - STAT 372 - Mathematical Statistics
#   - STAT 378 - Applied Regression Analysis
#   - MATH 471 - Markov Models
#   - STAT 499 - Research Project
# - Electives from 300+ and 400-level STAT courses
#
# ### Honors in Mathematics
# The program exists and is described as **flexible**, allowing students to design their degree for either general liberal education or specific career goals. However, I don't have the detailed course requirements available.
#
# ## For a Complete Comparison:
#
# I'd recommend:
# 1. Visiting the [Faculty of Science webpage](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/undergraduate-studies/programs/index.html)
# 2. Consulting with an academic advisor in the Department of Mathematical and Statistical Sciences
#
# They can provide detailed information about the Mathematics Honors program requirements and help you understand which program best suits your interests!

# %% [markdown]
# ### Q41: If I complete STAT 151, what statistics courses can I take next?
#
# **Time:** 4.9s
#
# ---
#
# # Statistics Courses After STAT 151
#
# Based on the information available to me, I can confirm that **STAT 151: Introduction to Applied Statistics I** is an entry-level, first-year course with no prerequisites.
#
# However, I don't have specific details about which statistics courses have STAT 151 as a prerequisite or what the recommended progression is for statistics courses after completing STAT 151.
#
# ## How to Find This Information
#
# For accurate information about course sequencing and what statistics courses you can take after STAT 151, I recommend:
#
# - **Visiting the [Department of Mathematical and Statistical Sciences website](https://www.ualberta.ca/en/mathematical-and-statistical-sciences/index.html)** for course descriptions and prerequisites
# - **Checking the [University of Alberta Calendar](https://calendar.ualberta.ca/)** for detailed course information
# - **Speaking with an academic advisor** in the Department of Mathematical and Statistical Sciences who can help you plan your statistics course sequence
#
# They'll be able to provide you with a clear pathway based on your program and academic goals!
